# %% [markdown]
# # DOOM
#
# A reinforcement learning model that can play doom.
#
# Note: ViZDoom subdirectory is a research environment created by M Wydmuch, M Kempka & W Jaśkowski (https://arxiv.org/abs/1809.03470)
#
#
# It is now maintained by the Farama-Foundation. Cloning it is needed to run this notebook.
#
# Clone from : `https://github.com/Farama-Foundation/ViZDoom`

# %%
# importing vizdoom
from vizdoom import *
# random
import random
# time
import time
# numpy
import numpy as np

# %%
# # creating a game instance
# game = DoomGame()
# game.load_config("./ViZDoom/scenarios/basic.cfg")
# game.init()

# %%
# creating a set of possible actions
# [MOVE_LEFT, MOVE_RIGHT, ATTACK]
actions = np.identity(3, dtype=np.uint8)
actions
# Out:
# array([[1, 0, 0],
#        [0, 1, 0],
#        [0, 0, 1]], dtype=uint8)

# %%
game.make_action??
# Out:
# Object `game.make_action` not found.

# %%
# episodes = 10

# # running a game for a number of episodes
# for episode in range(episodes):
#     # instantiating a new game
#     game.new_episode()

#     # while the game has not finished
#     while not game.is_episode_finished():
#         # current state of game
#         state = game.get_state()
#         # getting the pixel values for the current frame
#         img = state.screen_buffer
#         # other info (ie ammo/health)
#         info = state.game_variables

#         # reward for current action
#         # frame skip of 4, in order to let agent see outcome of input
#         reward = game.make_action(random.choice(actions),4)
#         print("\treward:", reward)

#         time.sleep(0.02)
#     print("Result:", game.get_total_reward())
#     time.sleep(2)

# %%
# game.close()

# %% [markdown]
# # OpenAI Gym
#
# making stuff work with openAI gym environment

# %%
# getting the openAI gym
import gym
# import Env class to make custom environments
from gym import Env, spaces

# import spaces to define action and observation spaces
from gym.spaces import Discrete, Box
# import opencv for greyscaling image (faster training)
import cv2

# matplotlib for some extra visualization
from matplotlib import pyplot as plt

# %%
# randomly sampling from the action space
actions[Discrete(3).sample()]
# Out:
# array([1, 0, 0], dtype=uint8)

# %%
# creating vizdoom openAI env

class VizDoomGym(Env):
    
    def __init__(self, render=False):
        # what happens when class instantiated
        # creating a game instance
        
        self.game = DoomGame()
        self.game.load_config("./ViZDoom/scenarios/basic.cfg")

        # not rendering images during training saves a lot of compute

        if (render==False):
            self.game.set_window_visible(False)
        else:
            self.game.set_window_visible(True)

        self.game.init()

        # creating observation space
            # this creates an openAI-compatible observation space
            # observation is a 3x240x320 image (3 rgb channels)
            # but then is compressed by grayscale to 100x160x1
        self.observation_space = Box(low=0, high=255, shape=(100,160,1), dtype=np.uint8)

        # creating action space
            # 3 possible actions
        self.action_space = Discrete(3)


    
    def step(self, action):
        # take one step in the environment
        
        actions = np.identity(3, dtype=np.uint8)
        # take an action, which is passed in as an argument
        reward = self.game.make_action(actions[action], 4)

        # retrieving updated state of game
        if self.game.get_state(): # ensuring game is not on menu frame (which returns null)
            state = self.game.get_state().screen_buffer
            state = self.grayscale(state)
            ammo = self.game.get_state().game_variables[0]

            info2 = ammo
        else:
            state = np.zeros(self.observation_space.shape)
            info2 = 0

        info = {"info": info2}

        done = self.game.is_episode_finished()

        # return relevant info about gamestep
        return state, reward, done, info

    def render():
        # how to render the game/env
        # done by vizdoom
        pass

    def reset(self):
        # reset the environment
        # what to do once new episode starts
        
        self.game.new_episode()
        state = self.game.get_state().screen_buffer
        return self.grayscale(state)
    def grayscale(self, observation):
        # grayscale + resize frame

        gray = cv2.cvtColor(np.moveaxis(observation, 0, -1), cv2.COLOR_BGR2GRAY)
        # np.moveaxis(observation, 0, -1) moves the first axis to the last axis, necessary shape for cv2 manipulation

        # compressing image so that there are fewer pixels to process
        resize = cv2.resize(gray, (160,100), interpolation=cv2.INTER_CUBIC)
        state = np.reshape(resize, (100, 160, 1))
        return state
    
    def close(self):
        # close the game
        self.game.close()

# %%
# to check if environment set up correctly
from stable_baselines3.common import env_checker

# %%
# showing model, checking if it is set up correct
env = VizDoomGym(render=False)
state = env.reset()
plt.imshow(cv2.cvtColor(state, cv2.COLOR_BGR2RGB))

# checks
# env_checker.check_env(env)

env.close()

# %% [markdown]
# # Training the model!
#
# PPO Model design. Wiki: https://en.wikipedia.org/wiki/Proximal_policy_optimization

# %%
import os
from stable_baselines3.common.callbacks import BaseCallback

# %%
# for logging and saving models
class TrainAndLoggingCallback(BaseCallback):
    def __init__(self, check_freq, save_path, verbose=1):
        super(TrainAndLoggingCallback, self).__init__(verbose)
        self.check_freq = check_freq
        self.save_path = save_path

    def _init_callback(self):
        if self.save_path is not None:
            os.makedirs(self.save_path, exist_ok=True)

    def _on_step(self):
        if self.n_calls % self.check_freq == 0:
            model_path = os.path.join(self.save_path, 'best_model_{}'.format(self.n_calls))
            self.model.save(model_path)

        return True

# %%
CHECKPOINT_DIR = "./train/model_basic_1"
LOG_DIR = "./train/logs_basic_1"

# save model every 10,000 steps
callback = TrainAndLoggingCallback(check_freq=10000, save_path=CHECKPOINT_DIR)

# %% [markdown]
# # Training

# %%
from stable_baselines3 import PPO

# %%
# creating the model

env = VizDoomGym(render=False)

# %%
model = PPO('CnnPolicy', env, tensorboard_log=LOG_DIR, verbose=1, learning_rate=0.0001, n_steps=2048)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Wrapping the env in a VecTransposeImage.
# /Users/shaanyadav/opt/anaconda3/envs/sandbox-experiments/lib/python3.9/site-packages/stable_baselines3/common/vec_env/patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(

# %%
model.learn(total_timesteps=100000, callback=callback)
# Out:
# Logging to ./train/logs_basic_1/PPO_6
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 35.3     |
# |    ep_rew_mean     | -98.1    |
# | time/              |          |
# |    fps             | 302      |
# |    iterations      | 1        |
# |    time_elapsed    | 6        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 40.8        |
# |    ep_rew_mean          | -131        |
# | time/                   |             |
# |    fps                  | 114         |
# |    iterations           | 2           |
# |    time_elapsed         | 35          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.009680945 |
# |    clip_fraction        | 0.135       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | -0.00021    |
# |    learning_rate        | 0.0001      |
# |    loss                 | 1.27e+03    |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.000579   |
# |    value_loss           | 2.59e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 47.4        |
# |    ep_rew_mean          | -172        |
# | time/                   |             |
# |    fps                  | 88          |
# |    iterations           | 3           |
# |    time_elapsed         | 69          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.010870993 |
# |    clip_fraction        | 0.191       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | 0.00242     |
# |    learning_rate        | 0.0001      |
# |    loss                 | 1.01e+03    |
# |    n_updates            | 20          |
# |    policy_gradient_loss | 0.00051     |
# |    value_loss           | 2.73e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 49.1        |
# |    ep_rew_mean          | -185        |
# | time/                   |             |
# |    fps                  | 74          |
# |    iterations           | 4           |
# |    time_elapsed         | 110         |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.008630849 |
# |    clip_fraction        | 0.112       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | 0.138       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 1.56e+03    |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.00208    |
# |    value_loss           | 2.89e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 46           |
# |    ep_rew_mean          | -159         |
# | time/                   |              |
# |    fps                  | 68           |
# |    iterations           | 5            |
# |    time_elapsed         | 150          |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0057569677 |
# |    clip_fraction        | 0.0843       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.08        |
# |    explained_variance   | 0.234        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 1.02e+03     |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.00186     |
# |    value_loss           | 3.24e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 39.5        |
# |    ep_rew_mean          | -120        |
# | time/                   |             |
# |    fps                  | 65          |
# |    iterations           | 6           |
# |    time_elapsed         | 188         |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.008610871 |
# |    clip_fraction        | 0.142       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.08       |
# |    explained_variance   | 0.409       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 1.75e+03    |
# |    n_updates            | 50          |
# |    policy_gradient_loss | 0.00166     |
# |    value_loss           | 4.14e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 34          |
# |    ep_rew_mean          | -90.6       |
# | time/                   |             |
# |    fps                  | 63          |
# |    iterations           | 7           |
# |    time_elapsed         | 225         |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.018943662 |
# |    clip_fraction        | 0.246       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.05       |
# |    explained_variance   | 0.523       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 1.43e+03    |
# |    n_updates            | 60          |
# |    policy_gradient_loss | 0.00249     |
# |    value_loss           | 3.29e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 33.5        |
# |    ep_rew_mean          | -84.4       |
# | time/                   |             |
# |    fps                  | 62          |
# |    iterations           | 8           |
# |    time_elapsed         | 262         |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.008333212 |
# |    clip_fraction        | 0.233       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.05       |
# |    explained_variance   | 0.58        |
# |    learning_rate        | 0.0001      |
# |    loss                 | 1.1e+03     |
# |    n_updates            | 70          |
# |    policy_gradient_loss | 0.00566     |
# |    value_loss           | 3.43e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 32.8        |
# |    ep_rew_mean          | -77.2       |
# | time/                   |             |
# |    fps                  | 62          |
# |    iterations           | 9           |
# |    time_elapsed         | 297         |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.012520824 |
# |    clip_fraction        | 0.265       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.05       |
# |    explained_variance   | 0.462       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 2.23e+03    |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00226    |
# |    value_loss           | 4.18e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 32          |
# |    ep_rew_mean          | -73.1       |
# | time/                   |             |
# |    fps                  | 60          |
# |    iterations           | 10          |
# |    time_elapsed         | 336         |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.015952818 |
# |    clip_fraction        | 0.25        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.06       |
# |    explained_variance   | 0.461       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 2.28e+03    |
# |    n_updates            | 90          |
# |    policy_gradient_loss | 0.0072      |
# |    value_loss           | 4.05e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 30.5        |
# |    ep_rew_mean          | -71.1       |
# | time/                   |             |
# |    fps                  | 60          |
# |    iterations           | 11          |
# |    time_elapsed         | 371         |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.010605375 |
# |    clip_fraction        | 0.217       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.03       |
# |    explained_variance   | 0.468       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 2.08e+03    |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -4.57e-06   |
# |    value_loss           | 4.15e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 29.1       |
# |    ep_rew_mean          | -63        |
# | time/                   |            |
# |    fps                  | 60         |
# |    iterations           | 12         |
# |    time_elapsed         | 406        |
# |    total_timesteps      | 24576      |
# | train/                  |            |
# |    approx_kl            | 0.01317947 |
# |    clip_fraction        | 0.245      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.03      |
# |    explained_variance   | 0.622      |
# |    learning_rate        | 0.0001     |
# |    loss                 | 895        |
# |    n_updates            | 110        |
# |    policy_gradient_loss | -0.00525   |
# |    value_loss           | 2.57e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 20.5        |
# |    ep_rew_mean          | -5.3        |
# | time/                   |             |
# |    fps                  | 60          |
# |    iterations           | 13          |
# |    time_elapsed         | 441         |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.012252491 |
# |    clip_fraction        | 0.207       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.999      |
# |    explained_variance   | 0.643       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 1.04e+03    |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.00341    |
# |    value_loss           | 3.05e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 17.3        |
# |    ep_rew_mean          | 14          |
# | time/                   |             |
# |    fps                  | 60          |
# |    iterations           | 14          |
# |    time_elapsed         | 476         |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.024485737 |
# |    clip_fraction        | 0.259       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.925      |
# |    explained_variance   | 0.497       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 1.33e+03    |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.00579    |
# |    value_loss           | 3.05e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 25.4        |
# |    ep_rew_mean          | -40.4       |
# | time/                   |             |
# |    fps                  | 59          |
# |    iterations           | 15          |
# |    time_elapsed         | 514         |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.041688226 |
# |    clip_fraction        | 0.276       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.913      |
# |    explained_variance   | 0.42        |
# |    learning_rate        | 0.0001      |
# |    loss                 | 926         |
# |    n_updates            | 140         |
# |    policy_gradient_loss | 0.034       |
# |    value_loss           | 2.03e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 18.6        |
# |    ep_rew_mean          | 6.45        |
# | time/                   |             |
# |    fps                  | 59          |
# |    iterations           | 16          |
# |    time_elapsed         | 549         |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.023363607 |
# |    clip_fraction        | 0.326       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.964      |
# |    explained_variance   | 0.486       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 628         |
# |    n_updates            | 150         |
# |    policy_gradient_loss | 0.0168      |
# |    value_loss           | 2.32e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 15.2        |
# |    ep_rew_mean          | 26.9        |
# | time/                   |             |
# |    fps                  | 59          |
# |    iterations           | 17          |
# |    time_elapsed         | 585         |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.022198178 |
# |    clip_fraction        | 0.259       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.956      |
# |    explained_variance   | 0.499       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 1.54e+03    |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.00476    |
# |    value_loss           | 2.57e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 12.2       |
# |    ep_rew_mean          | 41.9       |
# | time/                   |            |
# |    fps                  | 59         |
# |    iterations           | 18         |
# |    time_elapsed         | 624        |
# |    total_timesteps      | 36864      |
# | train/                  |            |
# |    approx_kl            | 0.03129396 |
# |    clip_fraction        | 0.283      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.903     |
# |    explained_variance   | 0.464      |
# |    learning_rate        | 0.0001     |
# |    loss                 | 730        |
# |    n_updates            | 170        |
# |    policy_gradient_loss | -0.0097    |
# |    value_loss           | 1.47e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10.1        |
# |    ep_rew_mean          | 55.2        |
# | time/                   |             |
# |    fps                  | 58          |
# |    iterations           | 19          |
# |    time_elapsed         | 662         |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.026568856 |
# |    clip_fraction        | 0.271       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.877      |
# |    explained_variance   | 0.602       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 337         |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.00826    |
# |    value_loss           | 1.23e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 9.79        |
# |    ep_rew_mean          | 56.1        |
# | time/                   |             |
# |    fps                  | 58          |
# |    iterations           | 20          |
# |    time_elapsed         | 700         |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.025274161 |
# |    clip_fraction        | 0.316       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.76       |
# |    explained_variance   | 0.383       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 146         |
# |    n_updates            | 190         |
# |    policy_gradient_loss | 0.00183     |
# |    value_loss           | 430         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 9.22       |
# |    ep_rew_mean          | 60.6       |
# | time/                   |            |
# |    fps                  | 58         |
# |    iterations           | 21         |
# |    time_elapsed         | 740        |
# |    total_timesteps      | 43008      |
# | train/                  |            |
# |    approx_kl            | 0.03516022 |
# |    clip_fraction        | 0.267      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.691     |
# |    explained_variance   | 0.406      |
# |    learning_rate        | 0.0001     |
# |    loss                 | 230        |
# |    n_updates            | 200        |
# |    policy_gradient_loss | -0.0117    |
# |    value_loss           | 422        |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 8.34       |
# |    ep_rew_mean          | 65.1       |
# | time/                   |            |
# |    fps                  | 57         |
# |    iterations           | 22         |
# |    time_elapsed         | 780        |
# |    total_timesteps      | 45056      |
# | train/                  |            |
# |    approx_kl            | 0.03387133 |
# |    clip_fraction        | 0.24       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.604     |
# |    explained_variance   | 0.385      |
# |    learning_rate        | 0.0001     |
# |    loss                 | 164        |
# |    n_updates            | 210        |
# |    policy_gradient_loss | -0.00966   |
# |    value_loss           | 425        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.55        |
# |    ep_rew_mean          | 70          |
# | time/                   |             |
# |    fps                  | 57          |
# |    iterations           | 23          |
# |    time_elapsed         | 820         |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.025203468 |
# |    clip_fraction        | 0.192       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.529      |
# |    explained_variance   | 0.412       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 139         |
# |    n_updates            | 220         |
# |    policy_gradient_loss | 0.00396     |
# |    value_loss           | 312         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.68        |
# |    ep_rew_mean          | 74.9        |
# | time/                   |             |
# |    fps                  | 57          |
# |    iterations           | 24          |
# |    time_elapsed         | 857         |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.034997724 |
# |    clip_fraction        | 0.194       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.441      |
# |    explained_variance   | 0.469       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 62.6        |
# |    n_updates            | 230         |
# |    policy_gradient_loss | 0.00891     |
# |    value_loss           | 167         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.55        |
# |    ep_rew_mean          | 75.5        |
# | time/                   |             |
# |    fps                  | 57          |
# |    iterations           | 25          |
# |    time_elapsed         | 892         |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.030144552 |
# |    clip_fraction        | 0.166       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.365      |
# |    explained_variance   | 0.493       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 57.5        |
# |    n_updates            | 240         |
# |    policy_gradient_loss | 0.0164      |
# |    value_loss           | 132         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.88        |
# |    ep_rew_mean          | 79          |
# | time/                   |             |
# |    fps                  | 57          |
# |    iterations           | 26          |
# |    time_elapsed         | 932         |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.040118013 |
# |    clip_fraction        | 0.155       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.317      |
# |    explained_variance   | 0.556       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 38.4        |
# |    n_updates            | 250         |
# |    policy_gradient_loss | 0.00711     |
# |    value_loss           | 109         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 11.8       |
# |    ep_rew_mean          | 47.3       |
# | time/                   |            |
# |    fps                  | 56         |
# |    iterations           | 27         |
# |    time_elapsed         | 978        |
# |    total_timesteps      | 55296      |
# | train/                  |            |
# |    approx_kl            | 0.06460109 |
# |    clip_fraction        | 0.147      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.31      |
# |    explained_variance   | 0.615      |
# |    learning_rate        | 0.0001     |
# |    loss                 | 48.8       |
# |    n_updates            | 260        |
# |    policy_gradient_loss | 0.0205     |
# |    value_loss           | 89.3       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.93        |
# |    ep_rew_mean          | 74          |
# | time/                   |             |
# |    fps                  | 56          |
# |    iterations           | 28          |
# |    time_elapsed         | 1018        |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.063927725 |
# |    clip_fraction        | 0.209       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.35       |
# |    explained_variance   | 0.397       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 27.5        |
# |    n_updates            | 270         |
# |    policy_gradient_loss | 0.0321      |
# |    value_loss           | 221         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.81        |
# |    ep_rew_mean          | 79.1        |
# | time/                   |             |
# |    fps                  | 55          |
# |    iterations           | 29          |
# |    time_elapsed         | 1062        |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.045154855 |
# |    clip_fraction        | 0.201       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.261      |
# |    explained_variance   | 0.722       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 142         |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.0014     |
# |    value_loss           | 200         |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 6.11      |
# |    ep_rew_mean          | 77.6      |
# | time/                   |           |
# |    fps                  | 55        |
# |    iterations           | 30        |
# |    time_elapsed         | 1108      |
# |    total_timesteps      | 61440     |
# | train/                  |           |
# |    approx_kl            | 0.0328412 |
# |    clip_fraction        | 0.124     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.202    |
# |    explained_variance   | 0.552     |
# |    learning_rate        | 0.0001    |
# |    loss                 | 34.8      |
# |    n_updates            | 290       |
# |    policy_gradient_loss | 0.0208    |
# |    value_loss           | 70.6      |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 6.95       |
# |    ep_rew_mean          | 74         |
# | time/                   |            |
# |    fps                  | 54         |
# |    iterations           | 31         |
# |    time_elapsed         | 1162       |
# |    total_timesteps      | 63488      |
# | train/                  |            |
# |    approx_kl            | 0.03956589 |
# |    clip_fraction        | 0.101      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.174     |
# |    explained_variance   | 0.72       |
# |    learning_rate        | 0.0001     |
# |    loss                 | 31.3       |
# |    n_updates            | 300        |
# |    policy_gradient_loss | 0.0167     |
# |    value_loss           | 48.6       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 6.36       |
# |    ep_rew_mean          | 76.9       |
# | time/                   |            |
# |    fps                  | 53         |
# |    iterations           | 32         |
# |    time_elapsed         | 1216       |
# |    total_timesteps      | 65536      |
# | train/                  |            |
# |    approx_kl            | 0.07063365 |
# |    clip_fraction        | 0.137      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.193     |
# |    explained_variance   | 0.433      |
# |    learning_rate        | 0.0001     |
# |    loss                 | 65.1       |
# |    n_updates            | 310        |
# |    policy_gradient_loss | 0.0152     |
# |    value_loss           | 139        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.79        |
# |    ep_rew_mean          | 79.7        |
# | time/                   |             |
# |    fps                  | 53          |
# |    iterations           | 33          |
# |    time_elapsed         | 1272        |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.044285506 |
# |    clip_fraction        | 0.105       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.192      |
# |    explained_variance   | 0.652       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 12.9        |
# |    n_updates            | 320         |
# |    policy_gradient_loss | 0.0185      |
# |    value_loss           | 74.8        |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 5.73      |
# |    ep_rew_mean          | 79.7      |
# | time/                   |           |
# |    fps                  | 52        |
# |    iterations           | 34        |
# |    time_elapsed         | 1325      |
# |    total_timesteps      | 69632     |
# | train/                  |           |
# |    approx_kl            | 0.0295038 |
# |    clip_fraction        | 0.098     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.179    |
# |    explained_variance   | 0.736     |
# |    learning_rate        | 0.0001    |
# |    loss                 | 5.62      |
# |    n_updates            | 330       |
# |    policy_gradient_loss | 0.0231    |
# |    value_loss           | 40.3      |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.23        |
# |    ep_rew_mean          | 76.5        |
# | time/                   |             |
# |    fps                  | 51          |
# |    iterations           | 35          |
# |    time_elapsed         | 1379        |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.035672296 |
# |    clip_fraction        | 0.0822      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.148      |
# |    explained_variance   | 0.639       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 16.6        |
# |    n_updates            | 340         |
# |    policy_gradient_loss | 0.0125      |
# |    value_loss           | 75.2        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5.89       |
# |    ep_rew_mean          | 78.8       |
# | time/                   |            |
# |    fps                  | 51         |
# |    iterations           | 36         |
# |    time_elapsed         | 1433       |
# |    total_timesteps      | 73728      |
# | train/                  |            |
# |    approx_kl            | 0.06978783 |
# |    clip_fraction        | 0.113      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.131     |
# |    explained_variance   | 0.496      |
# |    learning_rate        | 0.0001     |
# |    loss                 | 39.1       |
# |    n_updates            | 350        |
# |    policy_gradient_loss | -0.00425   |
# |    value_loss           | 109        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.23        |
# |    ep_rew_mean          | 78          |
# | time/                   |             |
# |    fps                  | 51          |
# |    iterations           | 37          |
# |    time_elapsed         | 1483        |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.028117098 |
# |    clip_fraction        | 0.103       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.166      |
# |    explained_variance   | 0.778       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 16.9        |
# |    n_updates            | 360         |
# |    policy_gradient_loss | 0.0461      |
# |    value_loss           | 30.4        |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 5.65      |
# |    ep_rew_mean          | 80.1      |
# | time/                   |           |
# |    fps                  | 50        |
# |    iterations           | 38        |
# |    time_elapsed         | 1531      |
# |    total_timesteps      | 77824     |
# | train/                  |           |
# |    approx_kl            | 0.0991472 |
# |    clip_fraction        | 0.133     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.154    |
# |    explained_variance   | 0.702     |
# |    learning_rate        | 0.0001    |
# |    loss                 | 18        |
# |    n_updates            | 370       |
# |    policy_gradient_loss | 0.00719   |
# |    value_loss           | 48.8      |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.28        |
# |    ep_rew_mean          | 77.7        |
# | time/                   |             |
# |    fps                  | 50          |
# |    iterations           | 39          |
# |    time_elapsed         | 1578        |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.022683289 |
# |    clip_fraction        | 0.0677      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.138      |
# |    explained_variance   | 0.698       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 32.3        |
# |    n_updates            | 380         |
# |    policy_gradient_loss | 0.00228     |
# |    value_loss           | 51.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.75        |
# |    ep_rew_mean          | 79.6        |
# | time/                   |             |
# |    fps                  | 50          |
# |    iterations           | 40          |
# |    time_elapsed         | 1626        |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.099807754 |
# |    clip_fraction        | 0.0943      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.139      |
# |    explained_variance   | 0.801       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 2.18        |
# |    n_updates            | 390         |
# |    policy_gradient_loss | 0.0241      |
# |    value_loss           | 28.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.19        |
# |    ep_rew_mean          | 76.8        |
# | time/                   |             |
# |    fps                  | 50          |
# |    iterations           | 41          |
# |    time_elapsed         | 1673        |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.065781906 |
# |    clip_fraction        | 0.0902      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.108      |
# |    explained_variance   | 0.553       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 15.5        |
# |    n_updates            | 400         |
# |    policy_gradient_loss | 0.00326     |
# |    value_loss           | 80          |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 6.02       |
# |    ep_rew_mean          | 78         |
# | time/                   |            |
# |    fps                  | 49         |
# |    iterations           | 42         |
# |    time_elapsed         | 1721       |
# |    total_timesteps      | 86016      |
# | train/                  |            |
# |    approx_kl            | 0.09058737 |
# |    clip_fraction        | 0.102      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.0794    |
# |    explained_variance   | 0.624      |
# |    learning_rate        | 0.0001     |
# |    loss                 | 30.8       |
# |    n_updates            | 410        |
# |    policy_gradient_loss | 0.00962    |
# |    value_loss           | 75.1       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5.75       |
# |    ep_rew_mean          | 79.7       |
# | time/                   |            |
# |    fps                  | 49         |
# |    iterations           | 43         |
# |    time_elapsed         | 1769       |
# |    total_timesteps      | 88064      |
# | train/                  |            |
# |    approx_kl            | 0.03903599 |
# |    clip_fraction        | 0.0891     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.0916    |
# |    explained_variance   | 0.698      |
# |    learning_rate        | 0.0001     |
# |    loss                 | 17.1       |
# |    n_updates            | 420        |
# |    policy_gradient_loss | 0.0125     |
# |    value_loss           | 41.6       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.04        |
# |    ep_rew_mean          | 78.6        |
# | time/                   |             |
# |    fps                  | 49          |
# |    iterations           | 44          |
# |    time_elapsed         | 1817        |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.052927185 |
# |    clip_fraction        | 0.0875      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.108      |
# |    explained_variance   | 0.701       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 14.1        |
# |    n_updates            | 430         |
# |    policy_gradient_loss | 0.0146      |
# |    value_loss           | 46.1        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.42        |
# |    ep_rew_mean          | 81.2        |
# | time/                   |             |
# |    fps                  | 49          |
# |    iterations           | 45          |
# |    time_elapsed         | 1865        |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.023938067 |
# |    clip_fraction        | 0.0657      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0966     |
# |    explained_variance   | 0.805       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 23.2        |
# |    n_updates            | 440         |
# |    policy_gradient_loss | 0.0291      |
# |    value_loss           | 31          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.96        |
# |    ep_rew_mean          | 78.7        |
# | time/                   |             |
# |    fps                  | 49          |
# |    iterations           | 46          |
# |    time_elapsed         | 1913        |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.021827303 |
# |    clip_fraction        | 0.0696      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.095      |
# |    explained_variance   | 0.843       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 4.41        |
# |    n_updates            | 450         |
# |    policy_gradient_loss | 0.0339      |
# |    value_loss           | 19.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.86        |
# |    ep_rew_mean          | 79.2        |
# | time/                   |             |
# |    fps                  | 49          |
# |    iterations           | 47          |
# |    time_elapsed         | 1961        |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.011790242 |
# |    clip_fraction        | 0.0485      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0824     |
# |    explained_variance   | 0.843       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 4.52        |
# |    n_updates            | 460         |
# |    policy_gradient_loss | 0.00905     |
# |    value_loss           | 22.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.87        |
# |    ep_rew_mean          | 79.5        |
# | time/                   |             |
# |    fps                  | 48          |
# |    iterations           | 48          |
# |    time_elapsed         | 2008        |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.010551145 |
# |    clip_fraction        | 0.0485      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0696     |
# |    explained_variance   | 0.859       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 23.2        |
# |    n_updates            | 470         |
# |    policy_gradient_loss | 0.0064      |
# |    value_loss           | 20.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.71        |
# |    ep_rew_mean          | 79.9        |
# | time/                   |             |
# |    fps                  | 48          |
# |    iterations           | 49          |
# |    time_elapsed         | 2057        |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.015966807 |
# |    clip_fraction        | 0.0416      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0705     |
# |    explained_variance   | 0.926       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 2.11        |
# |    n_updates            | 480         |
# |    policy_gradient_loss | 0.00827     |
# |    value_loss           | 8.63        |
# -----------------------------------------

# %% [markdown]
# # Eval

# %%
from stable_baselines3.common.evaluation import evaluate_policy

# %%
# Reload model from disc
model = PPO.load('./train/model_basic_1/best_model_100000')

# %%
# Create rendered environment
env = VizDoomGym(render=True)

# %%
# Evaluate mean reward for 10 games
mean_reward, _ = evaluate_policy(model, env, n_eval_episodes=100)
mean_reward
# Out:
# /Users/shaanyadav/opt/anaconda3/envs/sandbox-experiments/lib/python3.9/site-packages/stable_baselines3/common/evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(

# %%
for episode in range(100): 
    obs = env.reset()
    done = False
    total_reward = 0
    while not done: 
        action, _ = model.predict(obs)
        obs, reward, done, info = env.step(action)
        time.sleep(0.25)
        total_reward += reward
    print('Total Reward for episode {} is {}'.format(episode,total_reward))
    time.sleep(2)
# Out:
# Total Reward for episode 75.0 is 0
# Total Reward for episode 76.0 is 1
# Total Reward for episode 72.0 is 2
# Total Reward for episode 71.0 is 3
# Total Reward for episode 75.0 is 4
# Total Reward for episode 71.0 is 5
# Total Reward for episode 87.0 is 6
# Total Reward for episode 79.0 is 7
# Total Reward for episode 72.0 is 8
# ---------------------------------------------------------------------------
# ViZDoomUnexpectedExitException            Traceback (most recent call last)
# Cell In[68], line 7
#       5 while not done:
#       6     action, _ = model.predict(obs)
# ----> 7     obs, reward, done, info = env.step(action)
#       8     time.sleep(0.25)
#       9     total_reward += reward
#
# Cell In[51], line 38, in VizDoomGym.step(self, action)
#      36 actions = np.identity(3, dtype=np.uint8)
#      37 # take an action, which is passed in as an argument
# ---> 38 reward = self.game.make_action(actions[action], 4)
#      40 # retrieving updated state of game
#      41 if self.game.get_state(): # ensuring game is not on menu frame (which returns null)
#
# ViZDoomUnexpectedExitException: Controlled ViZDoom instance exited unexpectedly.
